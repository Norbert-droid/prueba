# %%
import numpy as np
import pylab as py
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
x1 = [1,12]
y1 = [1,1]
x2 = [12]
y2 = [1]

# %%
plt.figure("pyplot_scatterplot",figsize=(7,3))
plt.title("Uso de las matemáticas")
plt.ylim(0.999,1.001)
plt.plot(x1,y1,color="green",markersize=20)
plt.plot(x2,y2,'ro',color="blue",markersize=20)
plt.axis('off')
# Out:
# (0.44999999999999996, 12.55, 0.999, 1.001)

# %%
x = 1
y = 4
x1 = [1,1]
y1 = [-0.1, 4]
x2 = [-0.1,1]
y2 = [4,4]

# %%
plt.figure(figsize=(7,7))
plt.title('Precio de velas', size=30)
#plt.ylabel('cantidad de \n dinero', size=20)
#h.set_rotation(0)
plt.xlabel('cantidad de \n velas', size=20)
plt.xlim(0,2)
plt.ylim(0,5)
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(7,7))
plt.title('Precio de velas', size=30)
plt.xlabel('cantidad de \n velas', size=20)
plt.plot(ejex,ejey,color="black",markersize=8)
plt.plot(1,0,'ro',color="blue",markersize=10)
plt.xlim(-0.1,2)
plt.ylim(-0.1,5)
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(7,7))
plt.title('Precio de velas', size=30)
plt.xlabel('cantidad de \n velas', size=20)
plt.plot(2,0,'ro',color="blue",markersize=10)
plt.xlim(-0.1,2)
plt.ylim(-0.1,5)
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(7,7))
plt.title('Precio de velas', size=30)
plt.ylabel('cantidad de \n dinero', size=20)
#h.set_rotation(0)
plt.xlabel('cantidad de \n velas', size=20)
plt.plot(x1,y1,'--',color="red",markersize=8)
plt.plot(x2,y2,'--',color="red",markersize=8)
plt.plot(x,y,'ro',color="blue",markersize=10)
plt.xlim(0,2)
plt.ylim(0,5)
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(7,7))
plt.title('Precio de velas', size=30)
plt.ylabel('cantidad de \n dinero', size=20)
plt.xlabel('cantidad de \n velas', size=20)
plt.plot(x1,y1,'--',color="red",markersize=8)
plt.plot(x2,y2,'--',color="red",markersize=8)
plt.plot(x,y,'ro',color="blue",markersize=10)
plt.plot(0,0,'ro',color="blue",markersize=10)
plt.xlim(-0.1,2)
plt.ylim(-0.1,5)
plt.grid(True)
plt.show()

# %%
x3 = np.linspace(0, 10, num=20)
y3 = 4*x3

# %%
plt.figure(figsize=(7,7))
plt.title('Precio de velas', size=30)
plt.ylabel('cantidad de \n dinero', size=20)
plt.xlabel('cantidad de \n velas', size=20)
plt.plot(x1,y1,'--',color="red",markersize=8)
plt.plot(x2,y2,'--',color="red",markersize=8)
plt.plot(x3,y3,color="blue",markersize=8)
plt.plot(x,y,'ro',color="blue",markersize=10)
plt.plot(0,0,'ro',color="blue",markersize=10)
plt.xlim(-0.1,10)
plt.ylim(-0.1,40)
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(7,7))
plt.title('Precio de velas', size=30)
plt.ylabel('cantidad de \n dinero', size=20)
plt.xlabel('cantidad de \n velas', size=20)
plt.plot(x1,y1,'--',color="red",markersize=8)
plt.plot(x2,y2,'--',color="red",markersize=8)
plt.plot(x3,y3,color="blue",markersize=8)
plt.plot(x,y,'ro',color="blue",markersize=10)
plt.plot(0,0,'ro',color="blue",markersize=10)
plt.xlim(-0.1,10)
plt.ylim(-0.1,10)
plt.grid(True)
plt.show()

# %%
x4 = [1.5,1.5]
y4 = [0,6]
x5 = [0,1.5]
y5 = [6,6]

# %%
plt.figure(figsize=(7,7))
plt.title('Precio de velas', size=30)
plt.ylabel('cantidad de \n dinero', size=20)
plt.xlabel('cantidad de \n velas', size=20)
plt.plot(x1,y1,'--',color="red",markersize=8)
plt.plot(x2,y2,'--',color="red",markersize=8)
plt.plot(x4,y4,'--',color="red",markersize=8)
#plt.plot(x5,y5,'--',color="red",markersize=8)
plt.plot(x3,y3,color="blue",markersize=8)
plt.plot(x,y,'ro',color="blue",markersize=10)
plt.plot(0,0,'ro',color="blue",markersize=10)
plt.xlim(-0.1,10)
plt.ylim(-0.1,10)
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(7,7))
plt.title('Precio de velas', size=30)
plt.ylabel('cantidad de \n dinero', size=20)
plt.xlabel('cantidad de \n velas', size=20)
plt.plot(x1,y1,'--',color="red",markersize=8)
plt.plot(x2,y2,'--',color="red",markersize=8)
plt.plot(x4,y4,'--',color="red",markersize=8)
plt.plot(x5,y5,'--',color="red",markersize=8)
plt.plot(x3,y3,color="blue",markersize=8)
plt.plot(x,y,'ro',color="blue",markersize=10)
plt.plot(0,0,'ro',color="blue",markersize=10)
plt.xlim(-0.1,10)
plt.ylim(-0.1,10)
plt.grid(True)
plt.show()
